# %% [markdown]
# <a href="https://colab.research.google.com/github/Devrafael112/atividades_datascience_pandas/blob/main/Atividade_LAB_21_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rafael Ferreira de Oliveira
# ## Atividade pré-processamento de dados

# %%
import pandas   as pd
import numpy    as np

# %%
df_emp_atv = pd.read_csv('empresas_ativas.csv')
df_emp_ina = pd.read_csv('empresas_inativas.csv')

# %%
df_emp_atv = pd.DataFrame(df_emp_atv)

# %%
df_emp_atv
# Out:
#          _id            cnpj                              razao_social  \
# 0          1  50669717000107                               ECOSAT LTDA
# 1          2  50669717000107                               ECOSAT LTDA
# 2          3  50669717000107                               ECOSAT LTDA
# 3          4  50669717000107                               ECOSAT LTDA
# 4          5  12859211000163  ASSOCIACAO DE MORADORES DE VILA AEROMOCA
# ...      ...             ...                                       ...
# 26745  26746  08150369000192             OFICINA DE AUTOS EDVALDO LTDA
# 26746  26747  08150369000192             OFICINA DE AUTOS EDVALDO LTDA
# 26747  26748  01612046000477                   ROLIMEC ROLAMENTOS LTDA
# 26748  26749  01612046000477                   ROLIMEC ROLAMENTOS LTDA
# 26749  26750  34131619000157                          ACO CONCEPT LTDA
#
#       nome_fantasia  cod_logradouro              nome_logradouro  \
# ...

# %%
df_emp_ina = pd.DataFrame(df_emp_ina)

# %%
df_emp_ina
# Out:
#        _id            cnpj                              razao_social  \
# 0        1  03561119000121                   ROTENO CONSTRUCOES LTDA
# 1        2  03561119000121                   ROTENO CONSTRUCOES LTDA
# 2        3  03561119000121                   ROTENO CONSTRUCOES LTDA
# 3        4  00388321000105             CAMADA OLISI CONSTRUCOES LTDA
# 4        5  00388321000105             CAMADA OLISI CONSTRUCOES LTDA
# ...    ...             ...                                       ...
# 7745  7746  12682838000191      AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7746  7747  12682838000191      AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7747  7748  12682838000191      AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7748  7749  32066331000110  AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
# 7749  7750  32066331000110  AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
#
#           nome_fantasia  cod_logradouro       nome_logradouro  \
# 0                   NaN            9342      Rua Azevedo Cruz
# ...

# %%
df_emp_atv.isnull().sum()
# Out:
# _id                            0
# cnpj                           0
# razao_social                   0
# nome_fantasia               5146
# cod_logradouro                 0
# nome_logradouro                0
# numero_residencia          17784
# numero_lote                    0
# cod_bairro                     0
# nome_bairro                    0
# situacao_empresa               0
# data_abertura_empresa          0
# data_encerramento          26749
# cod_grupo                      0
# nome_grupo                     0
# cnae                           0
# desc_atividade                 0
# atividade_principal            0
# atividade_vig_sanitaria        0
# atividade_predominante         0
# incomodo                       0
# latitude                    8725
# longitude                   8725
# dtype: int64

# %%
df_cp_emp_atv = df_emp_atv.copy()

# %%
df_cp_emp_atv.dropna(subset = ['nome_fantasia'],inplace = True)

# %%
df_cp_emp_atv.isnull().sum()
# Out:
# _id                            0
# cnpj                           0
# razao_social                   0
# nome_fantasia                  0
# cod_logradouro                 0
# nome_logradouro                0
# numero_residencia          14411
# numero_lote                    0
# cod_bairro                     0
# nome_bairro                    0
# situacao_empresa               0
# data_abertura_empresa          0
# data_encerramento          21604
# cod_grupo                      0
# nome_grupo                     0
# cnae                           0
# desc_atividade                 0
# atividade_principal            0
# atividade_vig_sanitaria        0
# atividade_predominante         0
# incomodo                       0
# latitude                    6951
# longitude                   6951
# dtype: int64

# %%
df_cp_emp_atv.dropna(subset = ['latitude', 'longitude'], inplace = True)

# %%
df_cp_emp_atv.isnull().sum()
# Out:
# _id                            0
# cnpj                           0
# razao_social                   0
# nome_fantasia                  0
# cod_logradouro                 0
# nome_logradouro                0
# numero_residencia           9509
# numero_lote                    0
# cod_bairro                     0
# nome_bairro                    0
# situacao_empresa               0
# data_abertura_empresa          0
# data_encerramento          14653
# cod_grupo                      0
# nome_grupo                     0
# cnae                           0
# desc_atividade                 0
# atividade_principal            0
# atividade_vig_sanitaria        0
# atividade_predominante         0
# incomodo                       0
# latitude                       0
# longitude                      0
# dtype: int64

# %%
df_cp_emp_atv.head()
# Out:
#     _id            cnpj                             razao_social  \
# 93   94  07540483000166  ADEILTON PEREIRA DA SILVA MERCEARIA EPP
# 94   95  07540483000166  ADEILTON PEREIRA DA SILVA MERCEARIA EPP
# 95   96  13800569000183        LUCENA & SILVA MERCADINHO LTDA ME
# 96   97  13800569000183        LUCENA & SILVA MERCADINHO LTDA ME
# 97   98  13800569000183        LUCENA & SILVA MERCADINHO LTDA ME
#
#                 nome_fantasia  cod_logradouro  \
# 93  MINE MERCADO FRIGO GRANJA           25577
# 94  MINE MERCADO FRIGO GRANJA           25577
# 95     MERCADINHO KI ECONOMIA           25577
# 96     MERCADINHO KI ECONOMIA           25577
# 97     MERCADINHO KI ECONOMIA           25577
#
#                            nome_logradouro numero_residencia numero_lote  \
# 93  Rua Expedicionário Francisco Vitoriano               NaN   22
# 94  Rua Expedicionário Francisco Vitoriano               NaN   22
# 95  Rua Expedicionário Francisco Vitoriano                50   50
# ...

# %%
df_emp_atv = df_cp_emp_atv.copy()

# %%
df_emp_atv
# Out:
#          _id            cnpj                             razao_social  \
# 93        94  07540483000166  ADEILTON PEREIRA DA SILVA MERCEARIA EPP
# 94        95  07540483000166  ADEILTON PEREIRA DA SILVA MERCEARIA EPP
# 95        96  13800569000183        LUCENA & SILVA MERCADINHO LTDA ME
# 96        97  13800569000183        LUCENA & SILVA MERCADINHO LTDA ME
# 97        98  13800569000183        LUCENA & SILVA MERCADINHO LTDA ME
# ...      ...             ...                                      ...
# 26743  26744  23552031000150  CAMES ENGENHARIA PROJETOS TECNICOS LTDA
# 26744  26745  23552031000150  CAMES ENGENHARIA PROJETOS TECNICOS LTDA
# 26747  26748  01612046000477                  ROLIMEC ROLAMENTOS LTDA
# 26748  26749  01612046000477                  ROLIMEC ROLAMENTOS LTDA
# 26749  26750  34131619000157                         ACO CONCEPT LTDA
#
#                    nome_fantasia  cod_logradouro  \
# 93     MINE MERCADO FRIGO GRANJA           25577
# ...

# %% [markdown]
# ---
#
#
#
# # Pré-processamento do Dataframe empresas ativas concluído

# %%
df_emp_ina
# Out:
#        _id            cnpj                              razao_social  \
# 0        1  03561119000121                   ROTENO CONSTRUCOES LTDA
# 1        2  03561119000121                   ROTENO CONSTRUCOES LTDA
# 2        3  03561119000121                   ROTENO CONSTRUCOES LTDA
# 3        4  00388321000105             CAMADA OLISI CONSTRUCOES LTDA
# 4        5  00388321000105             CAMADA OLISI CONSTRUCOES LTDA
# ...    ...             ...                                       ...
# 7745  7746  12682838000191      AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7746  7747  12682838000191      AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7747  7748  12682838000191      AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7748  7749  32066331000110  AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
# 7749  7750  32066331000110  AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
#
#           nome_fantasia  cod_logradouro       nome_logradouro  \
# 0                   NaN            9342      Rua Azevedo Cruz
# ...

# %%
df_emp_ina.isnull().sum()
# Out:
# _id                           0
# cnpj                          0
# razao_social                  0
# nome_fantasia              2611
# cod_logradouro                0
# nome_logradouro               0
# numero_residencia          5886
# numero_lote                   0
# cod_bairro                    0
# nome_bairro                   0
# situacao_empresa              0
# data_abertura_empresa         0
# data_encerramento          6103
# cod_grupo                     0
# nome_grupo                    0
# cnae                          0
# desc_atividade                0
# atividade_principal           0
# atividade_vig_sanitaria       0
# atividade_predominante        0
# incomodo                      0
# latitude                   6157
# longitude                  6157
# dtype: int64

# %%
df_cp_emp_ina = df_emp_ina.copy()

# %%
df_cp_emp_ina.dropna(subset = ['nome_fantasia'], inplace = True )

# %%
df_cp_emp_ina.isnull().sum()
# Out:
# _id                           0
# cnpj                          0
# razao_social                  0
# nome_fantasia                 0
# cod_logradouro                0
# nome_logradouro               0
# numero_residencia          3929
# numero_lote                   0
# cod_bairro                    0
# nome_bairro                   0
# situacao_empresa              0
# data_abertura_empresa         0
# data_encerramento          4131
# cod_grupo                     0
# nome_grupo                    0
# cnae                          0
# desc_atividade                0
# atividade_principal           0
# atividade_vig_sanitaria       0
# atividade_predominante        0
# incomodo                      0
# latitude                   4024
# longitude                  4024
# dtype: int64

# %%
df_cp_emp_ina
# Out:
#        _id            cnpj                                      razao_social  \
# 5        6  01428602000107  JOAO PEREIRA DOS SANTOS SERVICOS DE ALIMENTOS ME
# 6        7  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# 7        8  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# 8        9  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# 9       10  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# ...    ...             ...                                               ...
# 7745  7746  12682838000191              AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7746  7747  12682838000191              AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7747  7748  12682838000191              AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7748  7749  32066331000110          AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
# 7749  7750  32066331000110          AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
#
# ...

# %%
df_emp_ina = df_cp_emp_ina.copy()

# %%
df_emp_ina
# Out:
#        _id            cnpj                                      razao_social  \
# 5        6  01428602000107  JOAO PEREIRA DOS SANTOS SERVICOS DE ALIMENTOS ME
# 6        7  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# 7        8  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# 8        9  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# 9       10  12271079000174                   RODRIGO SILVESTRE DE SANTANA ME
# ...    ...             ...                                               ...
# 7745  7746  12682838000191              AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7746  7747  12682838000191              AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7747  7748  12682838000191              AMADEU TIBURCIO DE SANT ANNA NETO ME
# 7748  7749  32066331000110          AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
# 7749  7750  32066331000110          AJS SERVIÇOS ESCOLARES EDUCACIONAIS LTDA
#
# ...

# %% [markdown]
# ---
#
#
# # Pré-processamento do Dataframe de empresas inativas aparentemente concluído.
# Tive um pouco de dúvida sobre os campos que precisavam ser limpados
